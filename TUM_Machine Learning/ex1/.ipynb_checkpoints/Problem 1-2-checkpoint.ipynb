# %%
import numpy as np
from sklearn import datasets, model_selection
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %% [markdown]
# Loading dataset (to simplify sorting, make one matrix with X[:, last]=y)

# %%
def load_dataset():       
    f = open("01_homework_dataset.csv")
    f.readline()  # skip the header
    dataset = np.loadtxt(f, delimiter=",")
    X = dataset[:,:4]
    return X
X = load_dataset()
# Out:
# [[ 5.5  0.5  4.5  2. ]
#  [ 7.4  1.1  3.6  0. ]
#  [ 5.9  0.2  3.4  2. ]
#  [ 9.9  0.1  0.8  0. ]
#  [ 6.9 -0.1  0.6  2. ]
#  [ 6.8 -0.3  5.1  2. ]
#  [ 4.1  0.3  5.1  1. ]
#  [ 1.3 -0.2  1.8  1. ]
#  [ 4.5  0.4  2.   0. ]
#  [ 0.5  0.   2.3  1. ]
#  [ 5.9 -0.1  4.4  0. ]
#  [ 9.3 -0.2  3.2  0. ]
#  [ 1.   0.1  2.8  1. ]
#  [ 0.4  0.1  4.3  1. ]
#  [ 2.7 -0.5  4.2  1. ]]

# %% [markdown]
# Function, that count Gini index

# %%
def gini_index(X):
    a = np.array([0,0,0])
    for i in X:        
        if i[3] == 0:
            a[0] += 1
        elif i[3] == 1:
            a[1] += 1
        else:
            a[2] += 1
    #print(a)
    p = np.square(a/len(X))
    #print(p)
    return (1-sum(p))

# %% [markdown]
# Function, that split one matrix to two, from the given line

# %%
def splitting_array(X,n):
    return X[:n,:], X[n:,:]

# %% [markdown]
# Function, that count delta Gini

# %%
def count_delta(l, x1, x2,i):
    #print(x1,i, gini_index(x1), gini_index(x2))
    k = 1-(i*gini_index(x1)+(l-i)*gini_index(x2))/l
    #print ("k",k)
    return k

# %% [markdown]
# Function, that saves all the delta Gini (by given dimension) to array, and finding position of split, to reach maximum index

# %%
def split_by_inp(X, inp):
    X = X[X[:, inp].argsort()] 
    g_i = np.zeros(len(X)-1)
    for i in range(1, len(X)):
        x1, x2 = splitting_array(X,i)
        g_i[i-1]=count_delta(len(X), x1, x2,i)  
    plt.plot(g_i)
    plt.show()
    max_arg = np.argmax(g_i)
    print ("Dimension: {0}\nSplit position: {1}\nDelta Gini: {2}\nXl: {3}\nXr: {4}".
           format(inp+1,max_arg,np.max(g_i),X[max_arg,inp],X[max_arg+1,inp]))
    pass

# %% [markdown]
# Finding the position

# %%
iG_0 = gini_index(X)

for i in range(3):
    split_by_inp(X, i)
# Out:
# Dimension: 1
# Split position: 5
# Delta Gini: 0.7037037037037037
# Xl: 4.1
# Xr: 4.5
# Dimension: 2
# Split position: 11
# Delta Gini: 0.4111111111111111
# Xl: 0.3
# Xr: 0.4
# Dimension: 3
# Split position: 11
# Delta Gini: 0.4111111111111111
# Xl: 4.4
# Xr: 4.5
